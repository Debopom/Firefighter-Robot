# %%
def getBboxes(pred) : 
    predictions = pred['predictions']
    image_path = predictions[0]['image_path']  # Assuming it's the same for all predictions
    image = cv2.cvtColor(image_path, cv2.COLOR_BGR2RGB)

    # Iterate through predictions and draw bounding boxes
    for prediction in predictions:
        x, y, w, h = int(prediction['x']), int(prediction['y']), int(prediction['width']), int(prediction['height'])
        label = prediction['class']
        confidence = prediction['confidence']

        # Draw bounding box on the image
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Add label and confidence score to the bounding box
        text = f"{label}: {confidence:.2f}"
        cv2.putText(image, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    return image

# %%
from ultralytics import YOLO
model = YOLO('H:\Semester-12\Micro lab\Project\Fire_YOLOv8.pt')

# %%
import requests

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
import urllib.request
import numpy as np
from cvlib.object_detection import draw_bbox
import concurrent.futures
import urllib.request

url = 'http://192.168.0.103/cam-lo.jpg'
cv2.namedWindow("live transmission", cv2.WINDOW_AUTOSIZE)
while True:
    img_resp=urllib.request.urlopen(url)
    imgnp=np.array(bytearray(img_resp.read()),dtype=np.uint8)
    im = cv2.imdecode(imgnp,-1)
    pred = model.predict(im, confidence=20, overlap=30).json()
    if pred['predictions']:
        print('detected')
        image = getBboxes(pred)
        cv2.imshow('live transmission', image)
        plt.imshow(image)
        plt.axis('off')  # Turn off axis labels and ticks
        plt.show()
        try:
            requests.get("http://192.168.0.103/set-pin-high")  # Replace [ESP32_IP_ADDRESS] with actual IP
        except requests.exceptions.RequestException as e:
            print("Error sending request to ESP32:", e)
    else : 
        cv2.imshow('live transmission', im)
    cv2.imshow('live transmission',im)
    key=cv2.waitKey(5)
    if key==ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# detected
# detected
# detected
# detected
# detected
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13832\1074515372.py in <module>
#      14     imgnp=np.array(bytearray(img_resp.read()),dtype=np.uint8)
#      15     im = cv2.imdecode(imgnp,-1)
# ---> 16     pred = model.predict(im, confidence=20, overlap=30).json()
#      17     if pred['predictions']:
#      18         print('detected')
#
# ~\AppData\Roaming\Python\Python39\site-packages\roboflow\models\object_detection.py in predict(self, image_path, hosted, format, classes, overlap, confidence, stroke, labels)
#     218             resp = requests.post(self.api_url)
#     219
# --> 220         resp.raise_for_status()
#     221         # Return a prediction group if JSON data
#     222         if self.format == "json":
#
# ~\anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# HTTPError: 403 Client Error: Forbidden for url: https://detect.roboflow.com/fire-detection-rzosn/1?api_key=NQz573gCKrXQa2ubEUMz&name=YOUR_IMAGE.jpg&overlap=30&confidence=20&stroke=1&labels=false&format=json
